# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_Category_1_Atlantic_hurricanes'

response = requests.get(URL)

URL2 = 'https://en.wikipedia.org/wiki/List_of_Category_2_Atlantic_hurricanes'

response2 = requests.get(URL2)

URL3 = 'https://en.wikipedia.org/wiki/List_of_Category_3_Atlantic_hurricanes'

response3 = requests.get(URL3)

URL5 = 'https://en.wikipedia.org/wiki/List_of_Category_5_Atlantic_hurricanes'

response5 = requests.get(URL5)

URL4 = 'https://en.wikipedia.org/wiki/List_of_Category_4_Atlantic_hurricanes'

response4 = requests.get(URL4)

# %%
response.status_code
# Out:
# 200

# %%
response3.status_code
# Out:
# 200

# %%
response2.status_code
# Out:
# 200

# %%
response5.status_code
# Out:
# 200

# %%
response4.status_code
# Out:
# 200

# %%
soup= BS(response.text)

# %%
soup2= BS(response2.text)

# %%
soup3= BS(response3.text)

# %%
soup5= BS(response5.text)

# %%
soup4= BS(response4.text)

# %%
#table_html = str(soup.findAll('td')

#from IPython.core.display import HTML

#HTML(table_html)

# %%
cat1 = pd.read_html(str(soup.find_all('table', class_=  'wikitable')))[0]

# %%
cat2 = pd.read_html(str(soup2.find_all('table', class_=  'wikitable')))[0]

# %%
cat3 =pd.read_html(str(soup3.find_all('table', class_=  'wikitable')))[0]

# %%
cat4_1 = pd.read_html(str(soup4.find_all('table', class_=  'wikitable')))[1]

# %%
cat5 = pd.read_html(str(soup5.find_all('table', class_=  'wikitable')))[0]

# %%
cols = [-1]
cat1.drop(cat1.columns[cols], axis=1, inplace=True)
cat2.drop(cat2.columns[cols], axis=1, inplace=True)
cat5.drop(cat5.columns[cols], axis=1, inplace=True)

# %%
cat3.drop(cat3.loc[:, 'Refs':'Unnamed: 160'], axis=1, inplace=True)
cat3
# Out:
#                                                   Name  \
# 0                                          San Agapito
# 1                                               Mobile
# 2                                              Unnamed
# 3                                              Coastal
# 4                                    Middle Gulf Coast
# ..                                                 ...
# 158                                            Epsilon
# 159                                               Zeta
# 160                                              Grace
# 161                                              Larry
# 162  Overall reference for name, dates, duration, w...
#
#                                   Dates as aCategory 3  \
# 0                                      August 23, 1851
# 1                                   August 24–26, 1852
# 2                                 September 8–10, 1853
# 3                                  September 7–8, 1854
# 4                                September 15–16, 1855
# ..                                                 ...
# 158                        October 21–October 22, 2020
# 159                                   October 28, 2020
# 160                                    August 20, 2021
# 161                                September 4–8, 2021
# 162  Overall reference for name, dates, duration, w...
#
#                                       Duration( hours)  \
# 0                                                   24
# 1                                                   60
# 2                                                   60
# 3                                                   48
# 4                                                   24
# ..                                                 ...
# 158                                                 12
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162  Overall reference for name, dates, duration, w...
#
#                                   Sustainedwind speeds  \
# 0                                   115 mph (185 km/h)
# 1                                   115 mph (185 km/h)
# 2                                   115 mph (185 km/h)
# 3                                   125 mph (205 km/h)
# 4                                   125 mph (205 km/h)
# ..                                                 ...
# 158                                 115 mph (185 km/h)
# 159                                 115 mph (185 km/h)
# 160                                 120 mph (195 km/h)
# 161                                 125 mph (205 km/h)
# 162  Overall reference for name, dates, duration, w...
#
#                                               Pressure  \
# 0                                 960 hPa (28.35 inHg)
# 1                                 961 hPa (28.38 inHg)
# 2                                              Unknown
# 3                                 938 hPa (27.70 inHg)
# 4                                 950 hPa (28.05 inHg)
# ..                                                 ...
# 158                               952 hPa (28.11 inHg)
# 159                               970 hPa (28.64 inHg)
# 160                               967 hPa (28.56 inHg)
# 161                               955 hPa (28.20 inHg)
# 162  Overall reference for name, dates, duration, w...
#
#                                         Areas affected  \
# 0                                    Antilles, Florida
# 1      Southeastern United States (especially Alabama)
# 2                                        No land areas
# 3                              Georgia, South Carolina
# 4                               Louisiana, Mississippi
# ..                                                 ...
# 158                                            Bermuda
# 159  Cayman Islands, Jamaica, Central America, Yuca...
# 160  Lesser Antilles, Greater Antilles, Yucatán Pen...
# 161                              Bermuda, Newfoundland
# 162  Overall reference for name, dates, duration, w...
#
#                                                 Deaths  \
# 0                                                   23
# 1                                                  300
# 2                                                  NaN
# 3                                                   26
# 4                                                  NaN
# ..                                                 ...
# 158                                                  1
# 159                                                  9
# 160                                                 15
# 161                                                  7
# 162  Overall reference for name, dates, duration, w...
#
#                                            Damage(USD)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 158                                            Minimal
# 159                                       $4.4 billion
# 160                                       $513 million
# 161                                        $80 million
# 162  Overall reference for name, dates, duration, w...
#
# [163 rows x 8 columns]

# %%
cat1['Pressure']= cat1['Pressure'].str.split( expand=True)
cat1.head()
# Out:
#                             Name                 Duration  \
# 0                            One       June 25 – 28, 1851
# 1                            Two         July 5 – 6, 1851
# 2  Hurricane San Lorenzo of 1852    September 5 – 6, 1852
# 3                          Three   September 9 – 13, 1852
# 4                           Four  September 22 – 30, 1852
#
#   Sustainedwind speeds Pressure           Areas affected Deaths Damage(USD)
# 0    90 mph (150 km/h)      977            Texas, Mexico      1         NaN
# 1    90 mph (150 km/h)      978                   Mexico      0         NaN
# 2    80 mph (130 km/h)  Unknown  Puerto Rico, Hispaniola  ≥ 100         NaN
# 3    80 mph (130 km/h)      985     Florida, The Bahamas      0         NaN
# 4    90 mph (150 km/h)  Unknown          Leeward Islands      0         NaN

# %%
cat2['Pressure']= cat2['Pressure'].str.split( expand=True)
cat2.head()
# Out:
#     Name                 Duration Sustainedwind speeds Pressure  \
# 0   Five     October 6 – 11, 1852   105 mph (165 km/h)      969
# 1  Eight    October 19 – 22, 1853   105 mph (165 km/h)      996
# 2   Four  September 18 – 20, 1854   105 mph (165 km/h)      965
# 3    One           August 6, 1855   105 mph (165 km/h)  Unknown
# 4    Two     August 10 – 11, 1855   105 mph (165 km/h)  Unknown
#
#                         Areas affected   Deaths   Damage(USD)
# 0  Jamaica, Yucatán Peninsula, Florida  Unknown         Minor
# 1                     Florida, Georgia  Unknown   Significant
# 2                                Texas        4  $20 thousand
# 3                              Tampico  Unknown       Unknown
# 4                        No land areas        0          None

# %%
cat3['Pressure']= cat3['Pressure'].str.split( expand=True)
cat3.head()
# Out:
#                 Name   Dates as aCategory 3 Duration( hours)  \
# 0        San Agapito        August 23, 1851               24
# 1             Mobile     August 24–26, 1852               60
# 2            Unnamed   September 8–10, 1853               60
# 3            Coastal    September 7–8, 1854               48
# 4  Middle Gulf Coast  September 15–16, 1855               24
#
#   Sustainedwind speeds Pressure  \
# 0   115 mph (185 km/h)      960
# 1   115 mph (185 km/h)      961
# 2   115 mph (185 km/h)  Unknown
# 3   125 mph (205 km/h)      938
# 4   125 mph (205 km/h)      950
#
#                                     Areas affected Deaths Damage(USD)
# 0                                Antilles, Florida     23         NaN
# 1  Southeastern United States (especially Alabama)    300         NaN
# 2                                    No land areas    NaN         NaN
# 3                          Georgia, South Carolina     26         NaN
# 4                           Louisiana, Mississippi    NaN         NaN

# %%
cat5['Pressure']= cat5['Pressure'].str.split( expand=True)
cat5.head()
# Out:
#                         Name Dates atCategory 5intensity  \
# 0                     "Cuba"            October 19, 1924
# 1  "San Felipe IIOkeechobee"       September 13–14, 1928
# 2                  "Bahamas"         September 5–6, 1932
# 3                 "Camagüey"          November 5–8, 1932
# 4         "Cuba–Brownsville"             August 30, 1933
#
#   Duration atCategory 5intensity Maximumsustained winds Pressure  \
# 0                       12 hours     165 mph (270 km/h)      910
# 1                       12 hours     160 mph (260 km/h)      929
# 2                          1 day     160 mph (260 km/h)      921
# 3                 3 days 6 hours     175 mph (280 km/h)      915
# 4                       12 hours     160 mph (260 km/h)      930
#
#                                       Areas affected Deaths Damage(USD)
# 0  Central America, Mexico, CubaFlorida, The Bahamas     90         NaN
# 1  Lesser Antilles, The BahamasUnited States East...   4000         NaN
# 2            The Bahamas, Northeastern United States     16         NaN
# 3  Lesser Antilles, Jamaica, Cayman IslandsCuba, ...   3103         NaN
# 4        The Bahamas, Cuba, FloridaTexas, Tamaulipas    179         NaN

# %%
cat1.dtypes
# Out:
# Name                    object
# Duration                object
# Sustainedwind speeds    object
# Pressure                object
# Areas affected          object
# Deaths                  object
# Damage(USD)             object
# dtype: object

# %%
cat1[['Month', 'Year']] = cat1.Duration.str.split(', ',1, expand=True)
cat1.head()
# Out:
#                             Name                 Duration  \
# 0                            One       June 25 – 28, 1851
# 1                            Two         July 5 – 6, 1851
# 2  Hurricane San Lorenzo of 1852    September 5 – 6, 1852
# 3                          Three   September 9 – 13, 1852
# 4                           Four  September 22 – 30, 1852
#
#   Sustainedwind speeds Pressure           Areas affected Deaths Damage(USD)  \
# 0                   90      977            Texas, Mexico      1         NaN
# 1                   90      978                   Mexico      0         NaN
# 2                   80  Unknown  Puerto Rico, Hispaniola  ≥ 100         NaN
# 3                   80      985     Florida, The Bahamas      0         NaN
# 4                   90  Unknown          Leeward Islands      0         NaN
#
#                Month  Year Month_only
# 0       June 25 – 28  1851       June
# 1         July 5 – 6  1851       July
# 2    September 5 – 6  1852  September
# 3   September 9 – 13  1852  September
# 4  September 22 – 30  1852  September

# %%
cat2[['Month', 'Year']] = cat2.Duration.str.split(', ',1, expand=True)
cat2.head()
# Out:
#     Name                 Duration Sustainedwind speeds Pressure  \
# 0   Five     October 6 – 11, 1852                  105      969
# 1  Eight    October 19 – 22, 1853                  105      996
# 2   Four  September 18 – 20, 1854                  105      965
# 3    One           August 6, 1855                  105  Unknown
# 4    Two     August 10 – 11, 1855                  105  Unknown
#
#                         Areas affected   Deaths   Damage(USD)  \
# 0  Jamaica, Yucatán Peninsula, Florida  Unknown         Minor
# 1                     Florida, Georgia  Unknown   Significant
# 2                                Texas        4  $20 thousand
# 3                              Tampico  Unknown       Unknown
# 4                        No land areas        0          None
#
#                Month  Year Month_only
# 0     October 6 – 11  1852    October
# 1    October 19 – 22  1853    October
# 2  September 18 – 20  1854  September
# 3           August 6  1855     August
# 4     August 10 – 11  1855     August

# %%
cat3[['Month', 'Year']] = cat3['Dates as aCategory 3'].str.split(', ',1, expand=True)
cat3.head()
# Out:
#                 Name   Dates as aCategory 3 Duration( hours)  \
# 0        San Agapito        August 23, 1851               24
# 1             Mobile     August 24–26, 1852               60
# 2            Unnamed   September 8–10, 1853               60
# 3            Coastal    September 7–8, 1854               48
# 4  Middle Gulf Coast  September 15–16, 1855               24
#
#   Sustainedwind speeds Pressure  \
# 0                  115      960
# 1                  115      961
# 2                  115  Unknown
# 3                  125      938
# 4                  125      950
#
#                                     Areas affected Deaths Damage(USD)  \
# 0                                Antilles, Florida     23         NaN
# 1  Southeastern United States (especially Alabama)    300         NaN
# 2                                    No land areas    NaN         NaN
# 3                          Georgia, South Carolina     26         NaN
# 4                           Louisiana, Mississippi    NaN         NaN
#
#              Month  Year       Month_only
# 0        August 23  1851           August
# 1     August 24–26  1852           August
# 2   September 8–10  1853   September 8–10
# 3    September 7–8  1854    September 7–8
# 4  September 15–16  1855  September 15–16

# %%
cat5[['Month', 'Year']] = cat5['Dates atCategory 5intensity'].str.split(', ',1, expand=True)
cat5.head()
# Out:
#                         Name Dates atCategory 5intensity  \
# 0                     "Cuba"            October 19, 1924
# 1  "San Felipe IIOkeechobee"       September 13–14, 1928
# 2                  "Bahamas"         September 5–6, 1932
# 3                 "Camagüey"          November 5–8, 1932
# 4         "Cuba–Brownsville"             August 30, 1933
#
#   Duration atCategory 5intensity Maximumsustained winds Pressure  \
# 0                       12 hours                    165      910
# 1                       12 hours                    160      929
# 2                          1 day                    160      921
# 3                 3 days 6 hours                    175      915
# 4                       12 hours                    160      930
#
#                                       Areas affected Deaths Damage(USD)  \
# 0  Central America, Mexico, CubaFlorida, The Bahamas     90         NaN
# 1  Lesser Antilles, The BahamasUnited States East...   4000         NaN
# 2            The Bahamas, Northeastern United States     16         NaN
# 3  Lesser Antilles, Jamaica, Cayman IslandsCuba, ...   3103         NaN
# 4        The Bahamas, Cuba, FloridaTexas, Tamaulipas    179         NaN
#
#              Month  Year Month_only
# 0       October 19  1924    October
# 1  September 13–14  1928  September
# 2    September 5–6  1932  September
# 3     November 5–8  1932   November
# 4        August 30  1933     August

# %%
cat1['Month_only'] = [x.split(' ')[0] for x in cat1['Month']]
cat2['Month_only'] = [x.split(' ')[0] for x in cat2['Month']]
cat3['Month_only'] = [x.split(' ')[0] for x in cat3['Month']]
cat5['Month_only'] = [x.split(' ')[0] for x in cat5['Month']]

# %%
cat1['Sustainedwind speeds']= cat1['Sustainedwind speeds'].str.split( expand=True)
cat2['Sustainedwind speeds']= cat2['Sustainedwind speeds'].str.split( expand=True)
cat3['Sustainedwind speeds']= cat3['Sustainedwind speeds'].str.split( expand=True)
cat5['Maximumsustained winds']= cat5['Maximumsustained winds'].str.split( expand=True)

# %%
cat5.Year = cat5.Year.str[:4]
cat5
# Out:
#                                                  Name  \
# 0                                              "Cuba"
# 1                           "San Felipe IIOkeechobee"
# 2                                           "Bahamas"
# 3                                          "Camagüey"
# 4                                  "Cuba–Brownsville"
# 5                                           "Tampico"
# 6                                         "Labor Day"
# 7                                       "New England"
# 8                                               Carol
# 9                                               Janet
# 10                                             Esther
# 11                                             Hattie
# 12                                               Inez
# 13                                             Beulah
# 14                                            Camille
# 15                                              Edith
# 16                                              Anita
# 17                                              David
# 18                                              Allen
# 19                                            Gilbert
# 20                                               Hugo
# 21                                             Andrew
# 22                                              Mitch
# 23                                             Isabel
# 24                                               Ivan
# 25                                              Emily
# 26                                            Katrina
# 27                                               Rita
# 28                                              Wilma
# 29                                               Dean
# 30                                              Felix
# 31                                            Matthew
# 32                                               Irma
# 33                                              Maria
# 34                                            Michael
# 35                                             Dorian
# 36                                            Lorenzo
# 37  Overall reference for Name, dates, duration, w...
#
#                           Dates atCategory 5intensity  \
# 0                                    October 19, 1924
# 1                               September 13–14, 1928
# 2                                 September 5–6, 1932
# 3                                  November 5–8, 1932
# 4                                     August 30, 1933
# 5                                  September 21, 1933
# 6                                   September 3, 1935
# 7                               September 19–20, 1938
# 8                                   September 3, 1953
# 9                               September 27–28, 1955
# 10                                 September 17, 1961
# 11                                   October 31, 1961
# 12                              September 28–29, 1966
# 13                                 September 20, 1967
# 14                               August 16–18, 1969 †
# 15                                  September 9, 1971
# 16                                  September 2, 1977
# 17                                 August 30–31, 1979
# 18                                 August 5–9, 1980 †
# 19                              September 13–14, 1988
# 20                                 September 15, 1989
# 21                               August 23–24, 1992 †
# 22                                October 26–28, 1998
# 23                            September 11–14, 2003 †
# 24                             September 9–14, 2004 †
# 25                                      July 16, 2005
# 26                                 August 28–29, 2005
# 27                              September 21–22, 2005
# 28                                   October 19, 2005
# 29                               August 18–21, 2007 †
# 30                              September 3–4, 2007 †
# 31                                    October 1, 2016
# 32                              September 5–9, 2017 †
# 33                            September 18–20, 2017 †
# 34                                   October 10, 2018
# 35                                September 1–2, 2019
# 36                                 September 29, 2019
# 37  Overall reference for Name, dates, duration, w...
#
#                        Duration atCategory 5intensity Maximumsustained winds  \
# 0                                            12 hours                    165
# 1                                            12 hours                    160
# 2                                               1 day                    160
# 3                                      3 days 6 hours                    175
# 4                                            12 hours                    160
# 5                                            12 hours                    160
# 6                                            18 hours                    185
# 7                                            18 hours                    160
# 8                                            12 hours                    160
# 9                                            18 hours                    175
# 10                                           18 hours                    160
# 11                                            6 hours                    165
# 12                                              1 day                    165
# 13                                           18 hours                    160
# 14                                      1 day 6 hours                    175
# 15                                            6 hours                    160
# 16                                           12 hours                    175
# 17                                     1 day 18 hours                    175
# 18                                             3 days                    190
# 19                                              1 day                    185
# 20                                            6 hours                    160
# 21                                           16 hours                    175
# 22                                     1 day 18 hours                    180
# 23                                     1 day 18 hours                    165
# 24                                    2 days 12 hours                    165
# 25                                            6 hours                    160
# 26                                           18 hours                    175
# 27                                              1 day                    180
# 28                                           18 hours                    185
# 29                                              1 day                    175
# 30                                              1 day                    175
# 31                                           12 hours                    165
# 32                                             3 days                    180
# 33                            1 day 4 hours15 minutes                    175
# 34                                         30 minutes                    160
# 35                                      1 day 6 hours                    185
# 36                                            3 hours                    160
# 37  Overall reference for Name, dates, duration, w...                Overall
#
#    Pressure                                     Areas affected  \
# 0       910  Central America, Mexico, CubaFlorida, The Bahamas
# 1       929  Lesser Antilles, The BahamasUnited States East...
# 2       921            The Bahamas, Northeastern United States
# 3       915  Lesser Antilles, Jamaica, Cayman IslandsCuba, ...
# 4       930        The Bahamas, Cuba, FloridaTexas, Tamaulipas
# 5       929                         Jamaica, Yucatán Peninsula
# 6       892  The Bahamas, Florida, GeorgiaThe Carolinas, Vi...
# 7       940         Eastern United States, Southwestern Quebec
# 8       929              Bermuda, New England, Atlantic Canada
# 9       914                   Lesser Antilles, Central America
# 10      919                    East Coast of the United States
# 11      914                                    Central America
# 12      927                  Greater Antilles, Florida, Mexico
# 13      921                       The Caribbean, Mexico, Texas
# 14      900                     Cuba, United States Gulf Coast
# 15      943  The Caribbean, Central AmericaMexico, United S...
# 16      926                                             Mexico
# 17      924            The Caribbean, United States East coast
# 18      899  The Caribbean, Yucatán PeninsulaMexico, South ...
# 19      888  Jamaica, Venezuela, Central AmericaHispaniola,...
# 20      918            The Caribbean, United States East Coast
# 21      922     The Bahamas, Florida, United States Gulf Coast
# 22      905  Central America, Yucatán Peninsula, South Florida
# 23      915  Greater Antilles, BahamasEastern United States...
# 24      910  The Caribbean, Venezuela, United States Gulf C...
# 25      929           Windward Islands, Jamaica, Mexico, Texas
# 26      902                  Bahamas, United States Gulf Coast
# 27      895                     Cuba, United States Gulf Coast
# 28      882         Greater Antilles, Central America, Florida
# 29      905                     The Caribbean, Central America
# 30      929                                Nicaragua, Honduras
# 31      934  Antilles, Venezuela, ColombiaUnited States Eas...
# 32      914  Cape Verde, The Caribbean, Virgin IslandsCuba,...
# 33      908  Lesser Antilles, Virgin Islands, Puerto RicoDo...
# 34      919          Central America, United States Gulf Coast
# 35      910  Barbados, Lesser Antilles, Virgin Islands, Pue...
# 36      925                 Cabo Verde, Azores, Western Europe
# 37  Overall  Overall reference for Name, dates, duration, w...
#
#                                                Deaths  \
# 0                                                  90
# 1                                                4000
# 2                                                  16
# 3                                                3103
# 4                                                 179
# 5                                                 184
# 6                                                 408
# 7                                                 682
# 8                                                   5
# 9                                                1023
# 10                                                  7
# 11                                                319
# 12                                                756
# 13                                                 59
# 14                                                259
# 15                                                 37
# 16                                                 11
# 17                                               2068
# 18                                                269
# 19                                                318
# 20                                                107
# 21                                                 65
# 22                                              19325
# 23                                                 51
# 24                                                124
# 25                                                 17
# 26                                               1836
# 27                                                125
# 28                                                 87
# 29                                                 45
# 30                                                133
# 31                                                603
# 32                                                138
# 33                                               3057
# 34                                                 74
# 35                                                 84
# 36                                                 19
# 37  Overall reference for Name, dates, duration, w...
#
#                                           Damage(USD)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                          Extensive
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  Overall reference for Name, dates, duration, w...
#
#                          Month  Year Month_only
# 0                   October 19  1924    October
# 1              September 13–14  1928  September
# 2                September 5–6  1932  September
# 3                 November 5–8  1932   November
# 4                    August 30  1933     August
# 5                 September 21  1933  September
# 6                  September 3  1935  September
# 7              September 19–20  1938  September
# 8                  September 3  1953  September
# 9              September 27–28  1955  September
# 10                September 17  1961  September
# 11                  October 31  1961    October
# 12             September 28–29  1966  September
# 13                September 20  1967  September
# 14                August 16–18  1969     August
# 15                 September 9  1971  September
# 16                 September 2  1977  September
# 17                August 30–31  1979     August
# 18                  August 5–9  1980     August
# 19             September 13–14  1988  September
# 20                September 15  1989  September
# 21                August 23–24  1992     August
# 22               October 26–28  1998    October
# 23             September 11–14  2003  September
# 24              September 9–14  2004  September
# 25                     July 16  2005       July
# 26                August 28–29  2005     August
# 27             September 21–22  2005  September
# 28                  October 19  2005    October
# 29                August 18–21  2007     August
# 30               September 3–4  2007  September
# 31                   October 1  2016    October
# 32               September 5–9  2017  September
# 33             September 18–20  2017  September
# 34                  October 10  2018    October
# 35               September 1–2  2019  September
# 36                September 29  2019  September
# 37  Overall reference for Name  date    Overall

# %%
cat5.Year.unique()
# Out:
# array(['1924', '1928', '1932', '1933', '1935', '1938', '1953', '1955',
#        '1961', '1966', '1967', '1969', '1971', '1977', '1979', '1980',
#        '1988', '1989', '1992', '1998', '2003', '2004', '2005', '2007',
#        '2016', '2017', '2018', '2019', 'date'], dtype=object)
